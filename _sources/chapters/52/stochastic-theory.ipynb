# %% [markdown]
# # Stochastic Theory of Size Exclusion Chromatography
#
# ##

# %% [markdown]
# $$ \phi(\omega)=\exp \Big[ i \omega t_0 + n_1(\frac{1}{1 - i \omega \tau_1} - 1) \Big] $$
