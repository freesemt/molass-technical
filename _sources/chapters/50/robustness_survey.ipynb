# %% [markdown]
# # Robustness Survey
# ##

# %%
import sys
sys.path.insert(0, '../../../molass-library')
sys.path.insert(0, '../../../molass-legacy')
import os
import matplotlib.pyplot as plt
from molass.Local import get_local_settings
from molass.DataUtils.FolderWalker import walk_folders
from molass.Global.Options import set_molass_options
set_molass_options(flowchange='auto')
local_settings = get_local_settings()
DATA_ROOT_FOLDER = local_settings['DATA_ROOT_FOLDER']
from molass.DataObjects import SecSaxsData as SSD

output_folder = "figs"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for k, path in enumerate(walk_folders(DATA_ROOT_FOLDER)):
    if k < 2:
    # if k < 28:
    # if k < 42:
    # if k < 52:
    # if k < 75:
    # if k < 76:
    # if k < 89:
    # if k < 90:
    # if k < 95:
    # if k < 97:
    # if k < 125:
    # if k < 145:
    # if k < 155:
    # if k < 161:
    # if k < 166:
    # if k < 187:   # loop?
    # if k < 188:
    # if k < 189:
    # if k < 212:
    # if k < 235:
    # if k < 237:
        continue
    print([k], path)
    ssd = SSD(path, remove_bubbles=True)
    if ssd.uv is None:
        print("No UV data found in %s, skipping." % path)
        continue

    trimmed_ssd = ssd.trimmed_copy()
    corrected_ssd = trimmed_ssd.corrected_copy()
    reuslt = corrected_ssd.plot_compact(title=path, baseline=True)
    reuslt.savefig(os.path.join(output_folder, f"{k:03d}_corrected.png"))
    reuslt.close()
    decomposition = corrected_ssd.quick_decomposition(num_components=3)
    result1 = decomposition.plot_components(title=path)
    result1.savefig(os.path.join(output_folder, f"{k:03d}_egh.png"))
    result1.close()
    sdm_decomposition = decomposition.optimize_with_model('SDM')
    result2 = sdm_decomposition.plot_components(title=path)
    result2.savefig(os.path.join(output_folder, f"{k:03d}_sdm.png"))
    result2.close()
    edm_decomposition = decomposition.optimize_with_model('EDM')
    result3 = edm_decomposition.plot_components(title=path)
    result3.savefig(os.path.join(output_folder, f"{k:03d}_edm.png"))
    result3.close()

    if k > 3:
        # break  # Uncomment to stop after processing a few files
        pass
# Out:
# [2] C:\Users\takahashi\PyTools\Data\20160227\backsub
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 1.4771641928010542
# guess_init_params: M2= 67.4205953980038
# area ratio= 0.35961264615905414
# guess_init_params: M2= 70.40065188827805
# area ratio= 0.35083080125937005
# guess_init_params: M2= 161.2889105150306
# area ratio= 0.36861773576576534
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [3] C:\Users\takahashi\PyTools\Data\20160628
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Mapping\PeakMatcher.py:22: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   slope, intercept, r_value, p_value, std_err = linregress(x, y)
# area= 1.2418972920138738
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 3: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 59.709080889629355
# area ratio= 0.35043844112528716
# guess_init_params: M2= 165.2956598959891
# area ratio= 0.35804258979207
# guess_init_params: M2= 160.22270962476264
# area ratio= 0.3502856920078782
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [4] C:\Users\takahashi\PyTools\Data\20161006\OA01\Backsub
# zeros at the angular ends of error data have been replaced with the adjacent values.
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Mapping\PeakMatcher.py:22: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   slope, intercept, r_value, p_value, std_err = linregress(x, y)
# area= 1.1199413185867597
# SimpleGuinier aborted due to 1 <= 32
# make_guinier_plot: Error processing component 3: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 42.004245050595216
# area ratio= 0.350551261710276
# guess_init_params: M2= 41.78079525907471
# area ratio= 0.3553921643664331
# guess_init_params: M2= 43.06629161498986
# area ratio= 0.3456617614684658
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [5] C:\Users\takahashi\PyTools\Data\20161104\BL-10C\Ald
# area= 0.6102249259024266
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# guess_init_params: M2= 4.279235953662101
# area ratio= 0.3473657961173078
# guess_init_params: M2= 129.9822533492731
# area ratio= 0.34681655139175055
# guess_init_params: M2= 110.15644818362684
# area ratio= 0.21307650957886104
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [6] C:\Users\takahashi\PyTools\Data\20161104\BL-10C\OA
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# area= 0.7290414949606947
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 39.317043185719974
# area ratio= 0.35024470057803536
# guess_init_params: M2= 217.60679644789465
# area ratio= 0.35195879450737266
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# guess_init_params: M2= 134.99422822717463
# area ratio= 0.16859410936796287
# [7] C:\Users\takahashi\PyTools\Data\20161104\BL-10C\OA_Ald
# area= 0.6279231233816454
# SimpleGuinier aborted due to 0 <= 32
# SimpleGuinier aborted due to 0 <= 32
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 176.14788863856404
# area ratio= 0.3536247372851621
# guess_init_params: M2= 150.3999586424052
# area ratio= 0.3502545650374316
# guess_init_params: M2= 191.14568991911975
# area ratio= 0.30327865320671504
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [8] C:\Users\takahashi\PyTools\Data\20161104\BL-6A\AhRR
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.45555434588806043
# guess_init_params: M2= 2.7290590219911004
# area ratio= 0.34617759909384027
# guess_init_params: M2= 142.51398022121666
# area ratio= 0.3435099788457896
# guess_init_params: M2= 106.7567099189478
# area ratio= 0.21010921499380292
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# [9] C:\Users\takahashi\PyTools\Data\20161104\BL-6A\HIF
# zeros at the angular ends of error data have been replaced with the adjacent values.
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# area= 0.4998488028230568
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 112.56987895976965
# area ratio= 0.3507765088445878
# guess_init_params: M2= 104.97946764393679
# area ratio= 0.2641470461512236
# guess_init_params: M2= 104.77665382092405
# area ratio= 0.2637298703583206
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [10] C:\Users\takahashi\PyTools\Data\20161104\BL-6A\pH6
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.31309510652842687
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# guess_init_params: M2= 91.21118698958789
# area ratio= 0.35137520798340854
# guess_init_params: M2= 187.61661613184162
# area ratio= 0.35048778776907275
# guess_init_params: M2= 531.4833512365905
# area ratio= 0.3501571299700522
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [11] C:\Users\takahashi\PyTools\Data\20161104\BL-6A\pH7
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.21489977115104142
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 29.836874756422574
# area ratio= 0.34589404606119994
# guess_init_params: M2= 250.85880538965688
# area ratio= 0.2343919489071013
# guess_init_params: M2= 123.82541866516847
# area ratio= 0.1205884978706931
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [12] C:\Users\takahashi\PyTools\Data\20161113\SUB_TRN1
# area= 5.93027090396234
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 202.67104236043636
# area ratio= 0.3574416026961948
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# guess_init_params: M2= 203.0866322449368
# area ratio= 0.3648758290847197
# guess_init_params: M2= 191.9026959106129
# area ratio= 0.2485277224026599
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in multiply
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [13] C:\Users\takahashi\PyTools\Data\20161113\SUB_TRN1DBB
# area= 7.77184214875135
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 125.41865115739259
# area ratio= 0.39213960406547155
# guess_init_params: M2= 168.66429623017817
# area ratio= 0.3524432281152306
# guess_init_params: M2= 193.95486603399306
# area ratio= 0.35244603495899346
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [14] C:\Users\takahashi\PyTools\Data\20161113\SUB_TRN1PY
# area= 11.70253068319558
# guess_init_params: M2= 8.771204573616837
# area ratio= 0.35055574941553674
# guess_init_params: M2= 294.5438818132911
# area ratio= 0.3902044990408926
# guess_init_params: M2= 586.4685926918834
# area ratio= 0.3194694425108973
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [15] C:\Users\takahashi\PyTools\Data\20161113\SUB_TRN1_2
# area= 10.539566846698575
# guess_init_params: M2= 208.40316548506658
# area ratio= 0.35505285906397516
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# guess_init_params: M2= 208.39148201217932
# area ratio= 0.3823770414941741
# guess_init_params: M2= 257.5231418581966
# area ratio= 0.2465593596279372
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in multiply
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:139: RuntimeWarning: overflow encountered in exp
#   expB = np.exp(Beta)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: invalid value encountered in multiply
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:141: RuntimeWarning: invalid value encountered in multiply
#   denom = W*( expB * erfc(-Y) + erfc(Y) )
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:143: RuntimeWarning: invalid value encountered in divide
#   ret_y = numer / denom
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:141: RuntimeWarning: overflow encountered in multiply
#   denom = W*( expB * erfc(-Y) + erfc(Y) )
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:143: RuntimeWarning: invalid value encountered in divide
#   ret_y = numer / denom
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:139: RuntimeWarning: overflow encountered in exp
#   expB = np.exp(Beta)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: invalid value encountered in multiply
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:141: RuntimeWarning: invalid value encountered in multiply
#   denom = W*( expB * erfc(-Y) + erfc(Y) )
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:141: RuntimeWarning: overflow encountered in multiply
#   denom = W*( expB * erfc(-Y) + erfc(Y) )
# [16] C:\Users\takahashi\PyTools\Data\20161119\Kosugi3a_Backsub
# zeros at the angular ends of error data have been replaced with the adjacent values.
# Failed to estimate mapping for matching peaks.  File "c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Mapping\SimpleMapper.py", line 252, in estimate_mapping_impl
#     return estimate_mapping_for_matching_peaks(xr_curve, xr_peaks, uv_curve, uv_peaks, debug=debug)
#   File "c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Mapping\SimpleMapper.py", line 195, in estimate_mapping_for_matching_peaks
#     return estimate_mapping_for_matching_peaks(xr_curve_, xr_peaks, uv_curve_, uv_peaks, retry=False, debug=debug)
#   File "c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Mapping\SimpleMapper.py", line 192, in estimate_mapping_for_matching_peaks
#     assert retry, "Mapping coverage is not acceptable after retry."
#            ^^^^^
# AssertionError: Mapping coverage is not acceptable after retry.
#
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# area= 0.2048618522908917
# guess_init_params: M2= 225.69452122981568
# area ratio= 0.35085160202351207
# guess_init_params: M2= 147.28960470792262
# area ratio= 0.16894327620421987
# guess_init_params: M2= 405.34179018538146
# area ratio= 0.22819016464039185
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [17] C:\Users\takahashi\PyTools\Data\20161119\Kosugi8_Backsub
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.2626541897681541
# make_guinier_plot: Error processing component 3: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 243.25129596680173
# area ratio= 0.35028118826548965
# guess_init_params: M2= 243.85786110874068
# area ratio= 0.31353444918732054
# guess_init_params: M2= 196.68490754009525
# area ratio= 0.1408359221523545
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [18] C:\Users\takahashi\PyTools\Data\20161124\Backsub1
# area= 0.4967666214574989
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# guess_init_params: M2= 20.189320583149247
# area ratio= 0.3499787943185536
# guess_init_params: M2= 244.13993961345406
# area ratio= 0.34491681181824957
# guess_init_params: M2= 168.30488257325877
# area ratio= 0.1344325134864726
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [19] C:\Users\takahashi\PyTools\Data\20161202
# area= 1.2413721780478966
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 135.25497734639262
# area ratio= 0.354373339925185
# guess_init_params: M2= 130.23903893424722
# area ratio= 0.35043875370625294
# guess_init_params: M2= 130.45705446390545
# area ratio= 0.3508947066454578
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [20] C:\Users\takahashi\PyTools\Data\20161205
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.8669782259557446
# guess_init_params: M2= 15.506716386423248
# area ratio= 0.33312490207009976
# guess_init_params: M2= 168.8394673509317
# area ratio= 0.3306971982791047
# guess_init_params: M2= 163.62336719260233
# area ratio= 0.18572864928359054
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [21] C:\Users\takahashi\PyTools\Data\20161216\Backsub
# area= 2.3006754755714027
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 15.714691273976763
# area ratio= 0.3501409610301705
# guess_init_params: M2= 22.64023053113537
# area ratio= 0.35012302103959914
# guess_init_params: M2= 673.3202623690512
# area ratio= 0.3546238563743767
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [22] C:\Users\takahashi\PyTools\Data\20161216\Backsub_101_120
# area= 0.4384405184579946
# guess_init_params: M2= 204.68307966990398
# area ratio= 0.3500778288869158
# guess_init_params: M2= 429.76497483455114
# area ratio= 0.35012654615109895
# guess_init_params: M2= 563.1694583760462
# area ratio= 0.19986591082423902
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [23] C:\Users\takahashi\PyTools\Data\20170209\OAF_original\CA_output
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.3810735536031557
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 133.64175538216793
# area ratio= 0.35449161682323516
# guess_init_params: M2= 162.29411226056973
# area ratio= 0.35034719328113334
# guess_init_params: M2= 158.4709667107782
# area ratio= 0.27968705050244624
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [24] C:\Users\takahashi\PyTools\Data\20170209\OAGIwyatt_01
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 4.4827594723934725
# SimpleGuinier aborted due to 0 <= 32
# SimpleGuinier aborted due to 0 <= 32
# make_guinier_plot: Error processing component 1: 'SimpleGuinier' object has no attribute 'guinier_start'
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 80.59579237317274
# area ratio= 0.37869457226078707
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# guess_init_params: M2= 80.15229350798116
# area ratio= 0.3515194264708645
# guess_init_params: M2= 86.02544291710164
# area ratio= 0.3602910536585569
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in multiply
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [25] C:\Users\takahashi\PyTools\Data\20170209\OAGIwyatt_02
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 4.260561314908237
# SimpleGuinier aborted due to 3 <= 32
# SimpleGuinier aborted due to 2 <= 32
# make_guinier_plot: Error processing component 2: 'SimpleGuinier' object has no attribute 'guinier_start'
# make_guinier_plot: Error processing component 3: 'SimpleGuinier' object has no attribute 'guinier_start'
# guess_init_params: M2= 83.87196062630518
# area ratio= 0.3776399914536451
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# guess_init_params: M2= 81.68318005192157
# area ratio= 0.35124116865250504
# guess_init_params: M2= 81.6848953848918
# area ratio= 0.35956103378127585
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in multiply
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [26] C:\Users\takahashi\PyTools\Data\20170209\OA_Ald_Fer
# zeros at the angular ends of error data have been replaced with the adjacent values.
# area= 0.39779201219005567
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\PlotUtils\DecompositionPlot.py:88: RuntimeWarning: invalid value encountered in log
#   logy = np.log(pv[slice_])
# guess_init_params: M2= 129.25082500261757
# area ratio= 0.35442436814617806
# guess_init_params: M2= 167.81166120674408
# area ratio= 0.35036375655554336
# guess_init_params: M2= 168.17767860598104
# area ratio= 0.27995450977792635
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:134: RuntimeWarning: invalid value encountered in sqrt
#   W = np.sqrt(np.pi*tau/RPe)
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:135: RuntimeWarning: invalid value encountered in sqrt
#   Y = xi/(2*np.sqrt(tau/RPe))
# c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-legacy\molass_legacy\SecTheory\Edm.py:140: RuntimeWarning: overflow encountered in exp
#   numer = U*(expB - 1)*np.exp(-V)
# [27] C:\Users\takahashi\PyTools\Data\20170209\OA_Ald_Fer-stain
# zeros at the angular ends of error data have been replaced with the adjacent values.
# Try find_peaks with fewer parameters.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 47
#      44     print("No UV data found in %s, skipping." % path)
#      45     continue
# ---> 47 trimmed_ssd = ssd.trimmed_copy()
#      48 corrected_ssd = trimmed_ssd.corrected_copy()
#      49 reuslt = corrected_ssd.plot_compact(title=path, baseline=True)
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\DataObjects\SecSaxsData.py:372, in SecSaxsData.trimmed_copy(self, trimming, jranges, mapping)
#     370 start_time = time()
#     371 if trimming is None:
# --> 372     trimming = self.make_trimming(jranges=jranges, mapping=mapping, debug=False)
#     373 else:
#     374     assert jranges is None, "jranges must be None if trimming is specified."
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\DataObjects\SecSaxsData.py:268, in SecSaxsData.make_trimming(self, **kwargs)
#     266 from molass.Trimming.TrimmingUtils import make_trimming_impl
#     267 flowchange = False if self.trimmed else None
# --> 268 return make_trimming_impl(self, flowchange=flowchange, **kwargs)
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Trimming\TrimmingUtils.py:112, in make_trimming_impl(ssd, xr_qr, xr_mt, uv_wr, uv_mt, uv_fc, flowchange, ip_effect_info, nsigmas, nguiniers, jranges, mapping, debug)
#     110         xr_icurve = ssd.xr.get_icurve()
#     111         xr_mt = EghMoment(xr_icurve)
# --> 112     start, stop = xr_mt.get_nsigma_points(nsigmas)
#     113     xr_jslice = slice(start, stop)
#     115 # uv_slices
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Stats\Moment.py:144, in Moment.get_nsigma_points(self, n)
#     130 def get_nsigma_points(self, n):
#     131     """Get the indices of the x-values that are within n standard deviations from the mean.
#     132
#     133     Parameters
#    (...)    142         If no such points exist, returns (None, None).
#     143     """
# --> 144     M, std = self.get_meanstd()
#     145     try:
#     146         wanted_range = np.logical_and(M - n*std < self.x, self.x < M + n*std)
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Stats\Moment.py:108, in Moment.get_meanstd(self)
#      97 """Get the mean and standard deviation of the distribution.
#      98     If M and std are None, they will be computed using the processed y-values.
#      99
#    (...)    105     The standard deviation of the distribution.
#     106 """
#     107 if self.y_ is None:
# --> 108     y_ = self.get_y_()
#     109     self.M, self.std = compute_meanstd(self.x, y_)
#     110 return self.M, self.std
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Stats\EghMoment.py:45, in EghMoment.get_y_(self)
#      37 """Get the computed y values from the EGH decomposition.
#      38
#      39 Returns
#    (...)     42     The computed y values from the EGH decomposition.
#      43 """
#      44 if self.y_ is None:
# ---> 45     self.y_ = self.compute_egh_y()
#      46 return self.y_
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Stats\EghMoment.py:58, in EghMoment.compute_egh_y(self)
#      56 icurve = self.icurve
#      57 if self.num_peaks is None:
# ---> 58     self.num_peaks = len(icurve.get_peaks())
#      59 self.curves = decompose_icurve_impl(icurve, self.num_peaks)   # egh component
#      60 cy_list = []
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\DataObjects\Curve.py:126, in Curve.get_peaks(self, debug, **kwargs)
#     124     if self.type != 'i':
#     125         raise TypeError("get_peaks works only for i-curves")
# --> 126     self.peaks = get_peak_positions(self, debug=debug, **kwargs)
#     127 return self.peaks
#
# File c:\Users\takahashi\GitHub\molass-technical\chapters\50\../../../molass-library\molass\Peaks\Recognizer.py:56, in get_peak_positions(icurve, debug, **kwargs)
#      52     print("Try find_peaks with fewer parameters.")
#      53     peaks, _ = find_peaks(y,
#      54                           height=height
#      55                           )
# ---> 56     assert len(peaks) > 0
#      58 if debug:
#      59     from scipy.signal import peak_prominences
#
# AssertionError:
